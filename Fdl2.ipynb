# %%
import tensorflow as tf

# %%
from keras.models import Sequential
from keras.datasets import mnist

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train=x_train/255.0
x_test=x_test/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
import keras

# %%
model=Sequential()
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(128,activation='relu'))
model.add(keras.layers.Dense(10,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=["accuracy"])
H=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 16s 7ms/step - loss: 0.2593 - accuracy: 0.9267 - val_loss: 0.1365 - val_accuracy: 0.9589
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1098 - accuracy: 0.9678 - val_loss: 0.0995 - val_accuracy: 0.9692
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0764 - accuracy: 0.9769 - val_loss: 0.0978 - val_accuracy: 0.9692
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0573 - accuracy: 0.9825 - val_loss: 0.0777 - val_accuracy: 0.9756
# Epoch 5/5
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0429 - accuracy: 0.9869 - val_loss: 0.0830 - val_accuracy: 0.9742

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print("loss=%.3f"%test_loss)
print("accuracy=%.3f"%test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0830 - accuracy: 0.9742
# loss=0.083
# accuracy=0.974

# %%
n=random.randint(0,9999)
plt.imshow(x_test[n])
plt.show()
predict=model.predict(x_test)

print("The displayed number is : ",np.argmax(predict[n]))
# Out:
# 313/313 [==============================] - 1s 2ms/step
# The displayed number is :  0

# %%
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
